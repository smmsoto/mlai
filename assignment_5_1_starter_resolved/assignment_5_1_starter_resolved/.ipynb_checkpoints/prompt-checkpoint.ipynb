# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
from scipy.stats import uniform
from scipy.stats import norm
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
#This method provides information about a DataFrame including the index dtype and columns, non-null values, and memory usage.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
#This will help us to identify which data is missing NaN or null
missing_data_summary = data.isnull().sum()
print("Summary of missing data:")
print(missing_data_summary)
# Out:
# Summary of missing data:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
#len(data) will return the number of rows in the DataFrame
len(data)
# Out:
# 12684

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %% [markdown]
# ### Car

# %%
##Delete car colum as it is missing more than 90% of the data 
del data['car']

# %% [markdown]
# ### Bar

# %%
#Bar is missing 107 values , I will create a new category "Missing" to assign those values
data['Bar'] = data['Bar'].fillna('missing')
data['Bar'].value_counts()
# Out:
# Bar
# never      5197
# less1      3482
# 1~3        2473
# 4~8        1076
# gt8         349
# missing     107
# Name: count, dtype: int64

# %% [markdown]
# ### CoffeeHouse

# %%
#less1 tends to have more values than the others; I will assign the missing data to that category
data['CoffeeHouse'] = data['CoffeeHouse'].fillna('less1')

# %%
data['CoffeeHouse'].value_counts()
# Out:
# CoffeeHouse
# less1    3602
# 1~3      3225
# never    2962
# 4~8      1784
# gt8      1111
# Name: count, dtype: int64

# %% [markdown]
# ### CarryAway

# %%
#1~3 tends to have more values than the others; I will assign the missing data to that category
data['CarryAway'] = data['CarryAway'].fillna('1~3')

# %%
data['CarryAway'].value_counts()
# Out:
# CarryAway
# 1~3      4823
# 4~8      4258
# less1    1856
# gt8      1594
# never     153
# Name: count, dtype: int64

# %% [markdown]
# ### RestaurantLessThan20

# %%
#1~3 tends to have more values than the others; I will assign the missing data to that category
data['RestaurantLessThan20'] = data['RestaurantLessThan20'].fillna('1~3')

# %%
data['RestaurantLessThan20'].value_counts()
# Out:
# RestaurantLessThan20
# 1~3      5506
# 4~8      3580
# less1    2093
# gt8      1285
# never     220
# Name: count, dtype: int64

# %% [markdown]
# ### Restaurant20To50

# %%
#1~3 tends to have more values than the others; I will assign the missing data to that category
data['Restaurant20To50'] = data['Restaurant20To50'].fillna('less1')

# %%
data['Restaurant20To50'].value_counts()
# Out:
# Restaurant20To50
# less1    6266
# 1~3      3290
# never    2136
# 4~8       728
# gt8       264
# Name: count, dtype: int64

# %%
#Double-check for missing data; there are no more columns with missing dataa
missing_data_summary = data.isnull().sum()
print("Summary of missing data:")
print(missing_data_summary)
# Out:
# Summary of missing data:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
#It is used to calculate the percentage of each unique value in the ‘Y’ column of the DataFrame data
(data.Y.value_counts(normalize=True) *100).round()
# Out:
# Y
# 1    57.0
# 0    43.0
# Name: proportion, dtype: float64

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
plt.figure(figsize=(10, 6))
data['coupon'].value_counts().plot(kind='barh', color='pink')
plt.title('Distribution of Coupon Types')
plt.xlabel('Frequency')
plt.ylabel('Coupon Type')
# Out:
# Text(0, 0.5, 'Coupon Type')

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
#Using Plotly to create a histogram for the 'temperature' column, it doesnt requiere additional operations as this temp colum is interger
fig = px.histogram(data, x='temperature', color= 'temperature', title='Histogram to visualize the temperature column.') 
# Show the plot 
fig.show()

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
## Filter the original DataFrame to include only rows where the 'coupon' column is 'Bar'
bar_coupons_df= data.query('coupon == "Bar"').copy()
bar_coupons_df
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 9      No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 13                Home      Alone   Sunny           55   6PM    Bar
# 17                Work      Alone   Sunny           55   7AM    Bar
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12663  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12664  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12667  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12670  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12682             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# ...

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
#calculate the percentage of bar coupons accepted in the ‘Y’ column 
accepted_proportion = (bar_coupons_df.Y.value_counts(normalize=True).get(1) * 100).round()
no_accepted_proportion = (bar_coupons_df.Y.value_counts(normalize=True).get(0) * 100).round()

print(f"The proportion of bar coupons accepted is {accepted_proportion}%")
# Out:
# The proportion of bar coupons accepted is 41.0%

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
#count the occurrences of each unique value in the ‘Bar’ column 
data['Bar'].value_counts()
# Out:
# Bar
# never      5197
# less1      3482
# 1~3        2473
# 4~8        1076
# gt8         349
# missing     107
# Name: count, dtype: int64

# %%
#data['Bar'].head()
#pd.DataFrame((data.groupby("Bar")['Y'].mean() * 100).round())

# Define the conditions for the two groups
bar_3_or_fewer = data['Bar'].isin(["never", "less1", "1~3"])
bar_more_than_3 = data['Bar'].isin(["4~8", "gt8"])

# Create filters for the two specific groups
condition1p3 = bar_3_or_fewer
condition2p3 = bar_more_than_3

# Filter the dataset for each group
group1p3 = data[condition1p3]
group2p3 = data[condition2p3]


# Calculate the acceptance rate for each group
acceptance_rate_group1p3 = (group1p3['Y'].mean() * 100).round()
acceptance_rate_group2p3 = (group2p3['Y'].mean() * 100).round()

#Print Results
print(f"Went to the Bar 3 or fewer times , Acceptance Rate (%): {acceptance_rate_group1p3}%")
print(f"Went to the Bar more than 3 times, Acceptance Rate (%): {acceptance_rate_group2p3}%")
# Out:
# Went to the Bar 3 or fewer times , Acceptance Rate (%): 56.0%
# Went to the Bar more than 3 times, Acceptance Rate (%): 62.0%

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
# Filter the dataset for drivers who go to a bar more than once a month and are over the age of 25
specific_group = data[(data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['age'].isin(['26', '31', '50plus', '36', '41', '46']))]

# Calculate the acceptance rate for this specific group
acceptance_rate_specific_group = (specific_group['Y'].mean() * 100).round()


# Filter the dataset for all other drivers. This uses the inverse ~ of your provided condition to filter all other drivers.
other_group = data[~((data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['age'].isin(['26', '31', '50plus', '36', '41', '46'])))]

acceptance_rate_others = (other_group['Y'].mean() * 100).round()

#Print Results
print(f"The acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 is: {acceptance_rate_specific_group}%")
print(f"All others: {acceptance_rate_others}%")
# Out:
# The acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 is: 62.0%
# All others: 55.0%

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
#count the occurrences of each unique value in the ‘passanger’ column 
data['passanger'].value_counts()
# Out:
# passanger
# Alone        7305
# Friend(s)    3298
# Partner      1075
# Kid(s)       1006
# Name: count, dtype: int64

# %%
#count the occurrences of each unique value in the ‘occupation’ column 
data['occupation'].value_counts()
# Out:
# occupation
# Unemployed                                   1870
# Student                                      1584
# Computer & Mathematical                      1408
# Sales & Related                              1093
# Education&Training&Library                    943
# Management                                    838
# Office & Administrative Support               639
# Arts Design Entertainment Sports & Media      629
# Business & Financial                          544
# Retired                                       495
# Food Preparation & Serving Related            298
# Healthcare Practitioners & Technical          244
# Healthcare Support                            242
# Community & Social Services                   241
# Legal                                         219
# Transportation & Material Moving              218
# Architecture & Engineering                    175
# Personal Care & Service                       175
# ...

# %%
# Filter the dataset for drivers who go to a bar more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.
specific_group2 = data[(data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['passanger'].isin(['Alone', 'Friend(s)', 'Partner'])) & (~data['occupation'].isin(['Farming Fishing & Forestry']))]

# Calculate the acceptance rate for this specific group
acceptance_rate_specific_group2 = (specific_group2['Y'].mean() * 100).round()

# Filter the dataset for all other drivers. This uses the inverse ~ of your provided condition to filter all other drivers.
other_group2 = data[~((data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['passanger'].isin(['Alone', 'Friend(s)', 'Partner'])) & (~data['occupation'].isin(['Farming Fishing & Forestry'])))]

# Calculate the acceptance rate for all other drivers
acceptance_rate_others2 = (other_group2['Y'].mean() * 100).round()

# Print the results
print(f"The acceptance rate for drivers who go to a bar more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry is: {acceptance_rate_specific_group2}%")
print(f"All others: {acceptance_rate_others2}%")
# Out:
# The acceptance rate for drivers who go to a bar more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry is: 62.0%
# All others: 55.0%

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
#count the occurrences of each unique value in the ‘maritalStatus’ column 
data['maritalStatus'].value_counts()
# Out:
# maritalStatus
# Married partner      5100
# Single               4752
# Unmarried partner    2186
# Divorced              516
# Widowed               130
# Name: count, dtype: int64

# %%
#count the occurrences of each unique value in the ‘income’ column 
data['income'].value_counts()
# Out:
# income
# $25000 - $37499     2013
# $12500 - $24999     1831
# $37500 - $49999     1805
# $100000 or More     1736
# $50000 - $62499     1659
# Less than $12500    1042
# $87500 - $99999      895
# $75000 - $87499      857
# $62500 - $74999      846
# Name: count, dtype: int64

# %%
#count the occurrences of each unique value in the ‘RestaurantLessThan20 column 
data['RestaurantLessThan20'].value_counts()
# Out:
# RestaurantLessThan20
# 1~3      5506
# 4~8      3580
# less1    2093
# gt8      1285
# never     220
# Name: count, dtype: int64

# %%
# Define the conditions for each group
bar_more_than_once = data['Bar'].isin(['1~3', '4~8', 'gt8'])
passenger_not_kid = data['passanger'].isin(['Alone', 'Friend(s)', 'Partner'])
not_widowed = data['maritalStatus'] != 'Widowed'
under_30 = data['age'].isin(['below21', '21', '26'])
cheap_restaurants_more_than_4 = data['RestaurantLessThan20'].isin(['4~8', 'gt8'])
income_less_than_50k = data['income'].isin(['less than $12500', '$12500 - $24999', '$25000 - $37499', '$37500 - $49999'])

# Create filters for the three specific groups
condition1p6 = bar_more_than_once & passenger_not_kid & not_widowed
condition2p6 = bar_more_than_once & under_30
condition3p6 = cheap_restaurants_more_than_4 & income_less_than_50k

# Filter the dataset for each group
group1p6 = data[condition1p6]
group2p6 = data[condition2p6]
group3p6 = data[condition3p6]

# Calculate the acceptance rate for each group
acceptance_rate_group1p6 = (group1p6['Y'].mean() * 100).round()
acceptance_rate_group2p6 = (group2p6['Y'].mean() * 100).round()
acceptance_rate_group3p6 = (group3p6['Y'].mean() * 100).round()

#Print Results
print(f"Bar > once a month, Passenger not a kid, Not widowed, acceptance Rate (%): {acceptance_rate_group1p6}%")
print(f"Bar > Bar > once a month, Under 30, Acceptance Rate (%): {acceptance_rate_group2p6}%")
print(f"Cheap restaurants > 4 times a month, Income < 50K, acceptance Rate (%): {acceptance_rate_group3p6}%")
# Out:
# Bar > once a month, Passenger not a kid, Not widowed, acceptance Rate (%): 62.0%
# Bar > Bar > once a month, Under 30, Acceptance Rate (%): 63.0%
# Cheap restaurants > 4 times a month, Income < 50K, acceptance Rate (%): 59.0%

# %%
# Data for CoffeeHouse acceptance rates by group
groups = [
    'Bar > once a month, Passenger not a kid, Not widowed',
    'Bar > once a month, Under 30',
    'Cheap restaurants > 4 times a month, Income < 50K'
]
acceptance_rates = [
    acceptance_rate_group1p6,
    acceptance_rate_group2p6,
    acceptance_rate_group3p6
]

# Create a DataFrame
acceptance_df = pd.DataFrame({
    'Group': groups,
    'Acceptance Rate (%)': acceptance_rates
})

# Create a bar chart
plt.figure(figsize=(11, 7))
sns.barplot(x='Acceptance Rate (%)', y='Group', data=acceptance_df, palette='Blues')
plt.title('Bar Acceptance Rates by Group')
plt.xlabel('Acceptance Rate (%)')
plt.ylabel('Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# - Drivers who frequent bars more than once a month are significantly more likely to accept bar coupons. This suggests that regular bar-goers are more receptive to bar-related promotions. Age Factor:
#
# - Younger drivers, particularly those under the age of 30, show a higher acceptance rate for bar coupons. This could imply that younger individuals are more open to spontaneous decisions related to social outings. Passenger Influence:
#
# - Drivers with passengers who are not kids are more likely to accept bar coupons. This indicates that having adult passengers might encourage decisions aligned with social activities, such as visiting a bar. Marital Status:
#
# - Drivers who are not widowed are more likely to accept bar coupons. This could suggest that people who are not dealing with the loss of a spouse might be more inclined towards social and leisure activities. Income and Dining Habits:
#
# - Drivers who frequently visit cheap restaurants and have an income less than 50K also show a higher acceptance rate for bar coupons. This might indicate a propensity for budget-conscious individuals to take advantage of promotions for social and leisure activities.
#
#  Summary Hypothesis: Drivers who accepted bar coupons are likely to be younger, frequent socializers (especially at bars), accompanied by adult passengers, and not currently widowed. Additionally, those who regularly dine out at inexpensive places and have moderate incomes also tend to accept bar coupons more often.
#
# These hypotheses can guide targeted marketing strategies for bar promotions, focusing on younger demographics, frequent bar-goers, and individuals in social settings with adults.

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %% [markdown]
# ## Investigating the Coffee House
#
# Now, we will lead you through an exploration of just the Coffee House related coupons.
#
# 1- Create a new DataFrame that contains just the Coffee House coupons.

# %%
data['coupon'].value_counts()
# Out:
# coupon
# Coffee House             3996
# Restaurant(<20)          2786
# Carry out & Take away    2393
# Bar                      2017
# Restaurant(20-50)        1492
# Name: count, dtype: int64

# %%
#Filter the original DataFrame to include only rows where the 'coupon' column is 'Coffee House'
Coffee_House_coupons_df= data.query('coupon == "Coffee House"').copy()
Coffee_House_coupons_df
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 12     No Urgent Place     Kid(s)   Sunny           55   6PM  Coffee House
# 15                Home      Alone   Sunny           80   6PM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 12656             Home      Alone   Snowy           30  10PM  Coffee House
# 12659             Work      Alone   Snowy           30   7AM  Coffee House
# 12674             Home      Alone   Rainy           55  10PM  Coffee House
# 12675             Home      Alone   Snowy           30  10PM  Coffee House
# 12681             Work      Alone   Snowy           30   7AM  Coffee House
#
# ...

# %% [markdown]
# 2- What proportion of Coffee_House coupons were accepted?

# %%
#calculate the percentage of bar coupons accepted in the ‘Y’ column 
accepted_ch_proportion = (Coffee_House_coupons_df.Y.value_counts(normalize=True).get(1) * 100).round()
no_accepted_ch_proportion = (Coffee_House_coupons_df.Y.value_counts(normalize=True).get(0) * 100).round()

# Create a DataFrame with the proportions
proportions_df = pd.DataFrame({
    'Category': ['Accepted', 'Not Accepted'],
    'Proportion': [accepted_ch_proportion, no_accepted_ch_proportion]
})

# Create the pie chart
fig = px.pie(proportions_df, names='Category', values='Proportion', title='Acceptance Proportions for Coffee House Coupons')

# Show the plot
fig.show()


#accepted_proportion = accepted_or_not_bar_coupons.loc[1]
print(f"The proportion of Coffe House coupons accepted is {accepted_ch_proportion}%")
# Out:
# The proportion of Coffe House coupons accepted is 50.0%

# %% [markdown]
# 3- Compare the acceptance rate between those who went to a Coffee House' 3 or fewer times a month to those who went more.

# %%
#count the occurrences of each unique value in the ‘CoffeeHouse" column 
data['CoffeeHouse'].value_counts()
# Out:
# CoffeeHouse
# less1    3602
# 1~3      3225
# never    2962
# 4~8      1784
# gt8      1111
# Name: count, dtype: int64

# %%
# Define the conditions for each group using query
CoffeeHouse_3_or_fewer = data.query('CoffeeHouse in ["never", "less1", "1~3"]')
CoffeeHouse_more_than_3 = data.query('CoffeeHouse in ["4~8", "gt8"]')

# Calculate the acceptance rate for each group
acceptance_rate_group1p8 = (CoffeeHouse_3_or_fewer['Y'].mean() * 100).round()
acceptance_rate_group2p8 = (CoffeeHouse_more_than_3['Y'].mean() * 100).round()

#Print Results
print(f"Went to the Coffee House 3 or fewer times , Acceptance Rate (%): {acceptance_rate_group1p8}%")
print(f"Went to the Coffee House more than 3 times, Acceptance Rate (%): {acceptance_rate_group1p8}%")
# Out:
# Went to the Coffee House 3 or fewer times , Acceptance Rate (%): 55.0%
# Went to the Coffee House more than 3 times, Acceptance Rate (%): 55.0%

# %% [markdown]
# 4- Compare the acceptance rates between those drivers who:
# - go to CoffeeHouse more than once a month, had passengers that were not a kid, and were not widowed OR
# - go to CoffeeHouse more than once a month and are under the age of 30 OR
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
# Define the conditions for each group
CoffeeHouse_more_than_once = data['CoffeeHouse'].isin(['1~3', '4~8', 'gt8'])
passenger_not_kid = data['passanger'].isin(['Alone', 'Friend(s)', 'Partner'])
not_widowed = data['maritalStatus'] != 'Widowed'
under_30 = data['age'].isin(['below21', '21', '26'])
cheap_restaurants_more_than_4 = data['RestaurantLessThan20'].isin(['4~8', 'gt8'])
income_less_than_50k = data['income'].isin(['less than $12500', '$12500 - $24999', '$25000 - $37499', '$37500 - $49999'])

# Create filters for the three specific groups
condition1p9 = CoffeeHouse_more_than_once & passenger_not_kid & not_widowed
condition2p9 = CoffeeHouse_more_than_once & under_30
condition3p9 = cheap_restaurants_more_than_4 & income_less_than_50k

# Filter the dataset for each group
group1p9 = data[condition1p9]
group2p9 = data[condition2p9]
group3p9 = data[condition3p9]

# Calculate the acceptance rate for each group
acceptance_rate_group1p9 = (group1p9['Y'].mean() * 100).round()
acceptance_rate_group2p9 = (group2p9['Y'].mean() * 100).round()
acceptance_rate_group3p9 = (group3p9['Y'].mean() * 100).round()

#Print Results
print(f"CoffeeHouse > once a month, Passenger not a kid, Not widowed, acceptance Rate (%): {acceptance_rate_group1p9}%")
print(f"CoffeeHouse > CoffeeHouse > once a month, Under 30, Acceptance Rate (%): {acceptance_rate_group2p9}%")
print(f"Cheap restaurants > 4 times a month, Income < 50K, acceptance Rate (%): {acceptance_rate_group3p9}%")
# Out:
# CoffeeHouse > once a month, Passenger not a kid, Not widowed, acceptance Rate (%): 64.0%
# CoffeeHouse > CoffeeHouse > once a month, Under 30, Acceptance Rate (%): 67.0%
# Cheap restaurants > 4 times a month, Income < 50K, acceptance Rate (%): 59.0%

# %%
# Data for CoffeeHouse acceptance rates by group
groups = [
    'CoffeeHouse > once a month, Passenger not a kid, Not widowed',
    'CoffeeHouse > once a month, Under 30',
    'Cheap restaurants > 4 times a month, Income < 50K'
]
acceptance_rates = [
    acceptance_rate_group1p9,
    acceptance_rate_group2p9,
    acceptance_rate_group3p9
]

# Create a DataFrame
acceptance_df = pd.DataFrame({
    'Group': groups,
    'Acceptance Rate (%)': acceptance_rates
})

# Create a bar chart
plt.figure(figsize=(11, 7))
sns.barplot(x='Acceptance Rate (%)', y='Group', data=acceptance_df, palette='viridis')
plt.title('Coffee House Acceptance Rates by Group')
plt.xlabel('Acceptance Rate (%)')
plt.ylabel('Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on these observations, what do you hypothesize about drivers who accepted the CoffeeHouse coupons?

# %% [markdown]
# Hypothesis:
#
# - Drivers who go to the CoffeeHouse more than once a month and are not accompanied by a kid, and are not widowed, are more likely to accept CoffeeHouse coupons. This group has a higher acceptance rate compared to the overall acceptance rate.
# - Younger drivers (under 30) who go to the CoffeeHouse more than once a month are also more likely to accept CoffeeHouse coupons, with the highest acceptance rate observed among the groups.
# - Drivers who frequent cheap restaurants more than 4 times a month and have an income of less than 50K also show a higher acceptance rate compared to the overall acceptance rate, but it is slightly lower than the first two specific groups.
